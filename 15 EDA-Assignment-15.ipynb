# %% [markdown]
# ## Explorator Data Analysis
# >This will show how we can do EDA using Pythin

# %% [markdown]
# ## Assignments

# %% [markdown]
# ## Three Important Steps to keep in Mind are:
# > 1- Understand The Data
#
# > 2- Clean the Data
#
# > 3- Find a relationship B/w Data

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read CSV file
df = pd.read_csv('shani.csv')
df
# Out:
#       Domain Code                        Domain  Area Code (FAO)      Area  \
# 0             TCL  Crops and livestock products              165  Pakistan
# 1             TCL  Crops and livestock products              165  Pakistan
# 2             TCL  Crops and livestock products              165  Pakistan
# 3             TCL  Crops and livestock products              165  Pakistan
# 4             TCL  Crops and livestock products              165  Pakistan
# ...           ...                           ...              ...       ...
# 77397         TCL  Crops and livestock products              165  Pakistan
# 77398         TCL  Crops and livestock products              165  Pakistan
# 77399         TCL  Crops and livestock products              165  Pakistan
# 77400         TCL  Crops and livestock products              165  Pakistan
# 77401         TCL  Crops and livestock products              165  Pakistan
#
#        Element Code          Element  Item Code (FAO)  \
# ...

# %%
df.isnull().sum()
# Out:
# Domain Code             0
# Domain                  0
# Area Code (FAO)         0
# Area                    0
# Element Code            0
# Element                 0
# Item Code (FAO)         0
# Item                    0
# Year Code               0
# Year                    0
# Unit                    0
# Value               16198
# Flag                52683
# Flag Description        0
# dtype: int64

# %%
# Handling the Problem of missing values
df.isnull().any()
# Out:
# Domain Code         False
# Domain              False
# Area Code (FAO)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (FAO)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value                True
# Flag                 True
# Flag Description    False
# dtype: bool

# %%
# Create a diskplot of the values
sns.distplot(df['Year'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
# Remove the Null values from Flag NaN
df.dropna(inplace=True)

# %%
df
# Out:
#       Domain Code                        Domain  Area Code (FAO)      Area  \
# 50            TCL  Crops and livestock products              165  Pakistan
# 52            TCL  Crops and livestock products              165  Pakistan
# 110           TCL  Crops and livestock products              165  Pakistan
# 112           TCL  Crops and livestock products              165  Pakistan
# 165           TCL  Crops and livestock products              165  Pakistan
# ...           ...                           ...              ...       ...
# 77206         TCL  Crops and livestock products              165  Pakistan
# 77263         TCL  Crops and livestock products              165  Pakistan
# 77266         TCL  Crops and livestock products              165  Pakistan
# 77333         TCL  Crops and livestock products              165  Pakistan
# 77390         TCL  Crops and livestock products              165  Pakistan
#
#        Element Code          Element  Item Code (FAO)  \
# ...

# %%
# Create a barplot of the Year
sns.barplot(x='Year', y='Item', data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Item'>

# %%
# Create scatterplot of the Year and Item
sns.scatterplot(x='Year', y='Item', data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Item'>

# %%
# Create a diskplot of the values
sns.distplot(df['Year'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
# Create a  of the Year
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Item'>

# %%
# Create a Lineplot of the Year and Item
sns.lineplot(x='Year', y='Item', data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Item'>
